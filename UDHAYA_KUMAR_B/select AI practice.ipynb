# %%
import google.generativeai as genai
import os

# %%
os.environ["GOOGLE_API_KEY"]= "AIzaSyAs2s__Rtzw76-rqtpqYPN964a6v6IUi_0"

# %%
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
model=genai.GenerativeModel("gemini-3-flash-preview")

# %%
def text_to_sql(question):
    prompt=f"""Convert the following natural language into SQL query.
    Table: students(id,name,marks)
    Question:{question}
    SQL:
    """
    response=model.generate_content(prompt)
    return response.text
question="What is the name of the student who scored the highest marks?"
sql_query=text_to_sql(question)
print(sql_query)
# Out:
# ```sql
# SELECT name FROM students ORDER BY marks DESC LIMIT 1;
# ```
